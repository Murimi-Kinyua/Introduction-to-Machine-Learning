# %% [markdown]
# <a href="https://colab.research.google.com/github/Murimi-Kinyua/Introduction-to-Machine-Learning/blob/main/INTRO_TO_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "review": ["Great book", "Not Useful", "Excellent"],
    "rating": [5, 2, 5]
}

df = pd.DataFrame(data)

df.head()   #df.head()
df.shape    #df.shape
df.columns  #df.columns
df["review"]
# Out:
# 0    Great book
# 1    Not Useful
# 2     Excellent
# Name: review, dtype: object

# %%
title = "this is a great book"
print(title)
print(title.lower())
print(title.upper())
len(title)
"great" in title
"bad" in title
# Out:
# this is a great book
# this is a great book
# THIS IS A GREAT BOOK
# False

# %%
def greet(name):
  print("hello " , name)

greet("joan")
# Out:
# hello  joan

# %%
ratings = [5, 4, 3, 5, 2]

for rating in ratings:
  print(rating)
# Out:
# 5
# 4
# 3
# 5
# 2

# %%
rating = 5

if rating >= 4:
  print("positive review")
else:

  print("negative review")
# Out:
# positive review

# %%
ratings = [5, 4, 3, 5, 2]

print(ratings)
print(ratings[0])
# Out:
# [5, 4, 3, 5, 2]
# 5

# %%
name = "joan"
age = 25
height = 1.65
is_student = True
